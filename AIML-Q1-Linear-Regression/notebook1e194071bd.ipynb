# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Correct path (tumhare output ke hisaab se)
train = pd.read_csv('/kaggle/input/competitions/house-prices-advanced-regression-techniques/train.csv')

# Features and target
X = train[['GrLivArea']]
y = train['SalePrice']

# Model
model = LinearRegression()
model.fit(X, y)

# Prediction
pred = model.predict(X)

print(pred[:5])
# Out:
# [201761.93968805 153767.53887136 209903.84696945 202511.85220081
#  254041.55486337]
