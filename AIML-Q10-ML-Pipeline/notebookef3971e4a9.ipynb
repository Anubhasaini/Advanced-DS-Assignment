# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier

# ✅ Correct path (tumhara wala)
train = pd.read_csv('/kaggle/input/competitions/spaceship-titanic/train.csv')
test = pd.read_csv('/kaggle/input/competitions/spaceship-titanic/test.csv')

# Drop unnecessary columns
train.drop(['Name', 'Cabin'], axis=1, inplace=True)
test.drop(['Name', 'Cabin'], axis=1, inplace=True)

# Fill missing values
train.fillna(method='ffill', inplace=True)
test.fillna(method='ffill', inplace=True)

# Encode categorical
le = LabelEncoder()
for col in train.select_dtypes(include='object').columns:
    train[col] = le.fit_transform(train[col].astype(str))
    if col in test.columns:
        test[col] = le.fit_transform(test[col].astype(str))

# Features & target
X = train.drop('Transported', axis=1)
y = train['Transported'].astype(int)

# Split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

# Model
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Prediction
pred = model.predict(test)

print("Predictions:", pred[:10])
# Out:
# /tmp/ipykernel_55/2057817383.py:15: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   train.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_55/2057817383.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_55/2057817383.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   test.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_55/2057817383.py:16: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test.fillna(method='ffill', inplace=True)
# Predictions: [1 0 1 1 1 1 1 1 1 1]
